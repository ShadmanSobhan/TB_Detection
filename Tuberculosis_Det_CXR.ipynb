# %% [markdown]
# ## Installation

# %%
import tensorflow as tf

if tf.config.list_physical_devices('GPU'):
    print("GPU is available")
else:
    print("GPU is not available")
# Out:
# 2024-08-07 14:39:43.553097: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-07 14:39:43.553155: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-07 14:39:43.554551: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# GPU is available

# %%
# !pip install tensorflow==2.15

# %%
# !pip install keras==2.15.0

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.15.0

# %%
import keras
print(keras.__version__)
# Out:
# 2.15.0

# %%
# !pip install tensorflow-addons
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tensorflow-addons) (21.3)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->tensorflow-addons) (3.1.1)
# Downloading tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 10.8 MB/s eta 0:00:00 0:00:01
# Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow-addons
#   Attempting uninstall: typeguard
#     Found existing installation: typeguard 4.1.5
#     Uninstalling typeguard-4.1.5:
#       Successfully uninstalled typeguard-4.1.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydata-profiling 4.6.4 requires numpy<1.26,>=1.16.0, but you have numpy 1.26.4 which is incompatible.
# ydata-profiling 4.6.4 requires typeguard<5,>=4.1.2, but you have typeguard 2.13.3 which is incompatible.
# Successfully installed tensorflow-addons-0.23.0 typeguard-2.13.3

# %%
# import system lib
import os
import time
import shutil
import pathlib
import itertools

# import data handling tools
import cv2
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

# import Deep learning Libraries
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras import regularizers
import tensorflow_addons as tfa
from keras import backend as K
# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

print ('modules loaded')
# Out:
# modules loaded
# /opt/conda/lib/python3.10/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %% [markdown]
# ## Input

# %%
# !kaggle datasets download -d shadmansobhan/tb-detection-4-august
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.6.17 / client 1.6.14)
# Dataset URL: https://www.kaggle.com/datasets/shadmansobhan/tb-detection-4-august
# License(s): MIT
# Downloading tb-detection-4-august.zip to /kaggle/working
# 100%|████████████████████████████████████████▉| 508M/508M [00:03<00:00, 199MB/s]
# 100%|█████████████████████████████████████████| 508M/508M [00:03<00:00, 152MB/s]

# %%
import zipfile
import os

# Path to the zip file
zip_file_path = '/kaggle/working/tb-detection-4-august.zip'

# Path to the directory where the zip file will be extracted
extract_to_path = '/kaggle/working/Image Files'

# Extract the zip file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_to_path)

print(f"Extracted {zip_file_path} to {extract_to_path}")
# Out:
# Extracted /kaggle/working/tb-detection-4-august.zip to /kaggle/working/Image Files

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ### histogram & Clahe

# %%
import cv2
import os

# Define the folder path containing the images
folder_path = '/kaggle/working/Image Files/4200 Segmented'

# Recursively traverse the directory tree
for root, _, files in os.walk(folder_path):
    for file in files:
        image_path = os.path.join(root, file)

        # Only process files with valid image extensions
        if file.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff')):
            image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

            # Check if the image was successfully loaded
            if image is None:
                print(f"Image at path '{image_path}' not found.")
                continue

            # Apply CLAHE (Contrast Limited Adaptive Histogram Equalization)
            clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
            clahe_image = clahe.apply(image)

            # Apply histogram equalization on the original image (not on CLAHE result)
            hist_eq_image = cv2.equalizeHist(image)

            # Apply CLAHE and then histogram equalization
            hist_eq_then_clahe_image = clahe.apply(hist_eq_image)

            # Save the modified image, replacing the original
            cv2.imwrite(image_path, hist_eq_then_clahe_image)

            print(f"Processed and replaced image at path '{image_path}'")
# Out:
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-184.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-47.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-168.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-374.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-329.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-179.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-122.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-128.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-356.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-440.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-283.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-340.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-690.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-55.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-335.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-5.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-325.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-361.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-391.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-285.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-205.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-221.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-8.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-202.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-453.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-368.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-639.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-241.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-154.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-489.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-669.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-80.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-498.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-17.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-488.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-196.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-321.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-660.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-45.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-79.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-141.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-366.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-89.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-580.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-483.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-566.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-478.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-482.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-507.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-30.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-259.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-95.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-142.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-462.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-306.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-645.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-688.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-593.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-369.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-46.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-537.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-464.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-352.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-225.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-476.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-531.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-684.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-263.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-109.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-320.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-219.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-208.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-430.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-396.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-147.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-338.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-145.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-551.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-502.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-414.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-104.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-300.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-353.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-346.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-627.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-458.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-204.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-499.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-116.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-382.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-35.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-110.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-312.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-595.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-13.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-609.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-491.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-206.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-26.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-427.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-296.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-612.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-513.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-632.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-44.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-653.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-146.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-466.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-156.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-422.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-432.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-333.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-417.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-642.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-316.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-449.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-410.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-634.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-51.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-181.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-267.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-177.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-617.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-295.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-27.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-203.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-3.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-214.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-446.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-88.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-292.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis-108.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Tuberculosis/Tuberculosis
png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-763.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-295.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-3054.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-3105.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-2863.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-814.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-3115.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-1731.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-2740.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-414.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-3181.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-3403.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-796.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-2816.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-2069.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-3281.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-900.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-3303.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-1978.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-2402.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-978.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-1852.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-1669.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-2589.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-870.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-2017.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-3481.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-2338.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-2874.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-2346.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-2511.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-589.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-290.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-2626.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-765.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-2815.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-539.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-2194.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-1459.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-2757.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-543.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-1173.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-3065.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-2532.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-495.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-2737.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-844.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-3143.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-376.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-2483.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-747.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-388.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-318.png'
# Processed and replaced image at path '/kaggle/working/Image Files/4200 Segmented/Normal/Normal-2446.png'

# %% [markdown]
# # **CSV FIle Generation based on Labelled Image**

# %%
data_dir = "/kaggle/working/Image Files/4200 Segmented"
filepaths = []
labels = []

folds = os.listdir(data_dir)
for fold in folds:
    foldpath = os.path.join(data_dir, fold)
    filelist = os.listdir(foldpath)
    for file in filelist:
        fpath = os.path.join(foldpath, file)
        filepaths.append(fpath)
        labels.append(fold)

# Concatenate data paths with labels into one dataframe
Fseries = pd.Series(filepaths, name= 'filepaths')
Lseries = pd.Series(labels, name='labels')
df = pd.concat([Fseries, Lseries], axis= 1)

# %%
df
# Out:
#                                               filepaths        labels
# 0     /kaggle/working/Image Files/4200 Segmented/Tub...  Tuberculosis
# 1     /kaggle/working/Image Files/4200 Segmented/Tub...  Tuberculosis
# 2     /kaggle/working/Image Files/4200 Segmented/Tub...  Tuberculosis
# 3     /kaggle/working/Image Files/4200 Segmented/Tub...  Tuberculosis
# 4     /kaggle/working/Image Files/4200 Segmented/Tub...  Tuberculosis
# ...                                                 ...           ...
# 4195  /kaggle/working/Image Files/4200 Segmented/Nor...        Normal
# 4196  /kaggle/working/Image Files/4200 Segmented/Nor...        Normal
# 4197  /kaggle/working/Image Files/4200 Segmented/Nor...        Normal
# 4198  /kaggle/working/Image Files/4200 Segmented/Nor...        Normal
# 4199  /kaggle/working/Image Files/4200 Segmented/Nor...        Normal
#
# [4200 rows x 2 columns]

# %%
print("Unique labels in the DataFrame:")
print(df['labels'].unique())
# Out:
# Unique labels in the DataFrame:
# ['Tuberculosis' 'Normal']

# %% [markdown]
# # Splitting data for training

# %%
# train dataframe
train_df, test_df = train_test_split(df,  train_size= 0.8, shuffle= True, random_state= 1)

# valid and test dataframe
# valid_df, test_df = train_test_split(dummy_df,  train_size= 0.5, shuffle= True, random_state= 123)

class_counts_train = train_df['labels'].value_counts()

# Print the counts for each class in the training set
print("Class counts in training set:")
print(class_counts_train)
# Out:
# Class counts in training set:
# labels
# Normal          2789
# Tuberculosis     571
# Name: count, dtype: int64

# %%
import cv2

def tf_equalize_histogram(image):
    values_range = tf.constant([0., 255.], dtype=tf.float32)

    # Convert image to float32 using tf.cast
    image_float = tf.cast(image, dtype=tf.float32)

    histogram = tf.histogram_fixed_width(image_float, values_range, 256)
    cdf = tf.cumsum(histogram)
    cdf_min = cdf[tf.reduce_min(tf.where(tf.greater(cdf, 0)))]

    img_shape = tf.shape(image)
    pix_cnt = img_shape[-3] * img_shape[-2]
    px_map = tf.round(tf.cast(cdf - cdf_min, dtype=tf.float32) * 255. / tf.cast(pix_cnt - 1, dtype=tf.float32))

    px_map = tf.cast(px_map, dtype=tf.uint8)

    # Use tf.gather to map values from px_map to the image
    eq_hist_img = tf.gather(px_map, tf.cast(image_float, dtype=tf.int32))

    return eq_hist_img

def preprocess_image(img):
    # img = img / 255.0
    img = tfa.image.equalize(img)
    img = tf.image.adjust_contrast(img, contrast_factor=1.2)

    # Normalize the image to the range [0, 1]
    # img = img / 255.0

    # Clip values to ensure they are in the valid range [0, 1]
    # img = tf.clip_by_value(img, 0.0, 1.0)

    # Convert the image to float32 if needed

    img = tf.cast(img, dtype=tf.float32)

    return img

# cropped image size
batch_size = 64
img_size = (224, 224)
channels = 3
img_shape = (img_size[0], img_size[1], channels)

# Recommended : use custom function for test data batch size, else we can use normal batch size.
ts_length = len(test_df)
test_batch_size = 16
#max(sorted([ts_length // n for n in range(1, ts_length + 1) if ts_length%n == 0 and ts_length/n <= 80]))
test_steps = ts_length // test_batch_size

# This function which will be used in image data generator for data augmentation, it just take the image and return it again.
def scalar(img):
    return img

tr_gen = ImageDataGenerator(
        # featurewise_center=True,
        # featurewise_std_normalization= True,
        horizontal_flip=False,  # Set to True for random horizontal flips
        vertical_flip=False,  # Set to False to disable vertical flips
        rotation_range=12,
        zoom_range=0.2,
        preprocessing_function = scalar
        )

ts_gen = ImageDataGenerator(preprocessing_function= scalar)

train_gen = tr_gen.flow_from_dataframe( train_df, x_col= 'filepaths', y_col= 'labels', target_size= img_size, class_mode= 'categorical',
                                    color_mode= 'rgb', shuffle= True, batch_size= batch_size)

# valid_gen = ts_gen.flow_from_dataframe( valid_df, x_col= 'filepaths', y_col= 'labels', target_size= img_size, class_mode= 'categorical',
#                                     color_mode= 'rgb', shuffle= True, batch_size= batch_size)

# Note: we will use custom test_batch_size, and make shuffle= false
test_gen = ts_gen.flow_from_dataframe( test_df, x_col= 'filepaths', y_col= 'labels', target_size= img_size, class_mode= 'categorical',
                                    color_mode= 'rgb', shuffle= False, batch_size= test_batch_size)
# Out:
# Found 3360 validated image filenames belonging to 2 classes.
# Found 840 validated image filenames belonging to 2 classes.

# %% [markdown]
# **Sample from training data**

# %%
g_dict = train_gen.class_indices     # defines dictionary {'class': index}
classes = list(g_dict.keys())       # defines list of dictionary's keys (classes), classes names : string
images, labels = next(train_gen)      # get a batch size samples from the generator


print("Class indices dictionary:", g_dict)
print("List of class names:", classes)
# Out:
# Class indices dictionary: {'Normal': 0, 'Tuberculosis': 1}
# List of class names: ['Normal', 'Tuberculosis']

# %%
plt.figure(figsize= (20, 20))

for i in range(16):
    plt.subplot(4, 4, i + 1)
    image = images[i] / 255       # scales data to range (0 - 255)
    plt.imshow(image)
    index = np.argmax(labels[i])  # get image index
    class_name = classes[index]   # get class of image
    plt.title(class_name, color= 'blue', fontsize= 12)
    plt.axis('off')
plt.show()

# %%
import pandas as pd
import tensorflow as tf
from tensorflow.keras import backend as K

# Example train_df for demonstration (replace with your actual data)
# train_df = pd.read_csv('your_data.csv')

# Get the value counts for the labels
label_counts = train_df['labels'].value_counts()

# Check the unique values in the labels
if len(label_counts) < 2:
    raise ValueError("There are not enough classes in the 'labels' column. Make sure there are at least two classes.")

# Extract the counts for each class
train_norm = label_counts.iloc[0]
train_tb = label_counts.iloc[1]

print('Percent of Tuberculosis/Normal : {} %'.format(100 * train_tb/train_norm))

# Create positive frequency and negative frequency
freq_pos = round((train_tb / train_norm), 2)
freq_neg = 1 - freq_pos

pos_weights = freq_neg
neg_weights = freq_pos
pos_contribution = freq_pos * pos_weights
neg_contribution = freq_neg * neg_weights

print(pos_contribution, neg_contribution)

# Create weighted loss function
def get_weighted_loss(pos_weights, neg_weights, epsilon=1e-7):
    def weighted_loss(y_true, y_pred):
        # Initialize loss to zero
        loss = 0.0
        # For each class, add average weighted loss for that class
        loss += K.mean(-(pos_weights * y_true * K.log(y_pred + epsilon) +
                         neg_weights * (1 - y_true) * K.log(1 - y_pred + epsilon)))
        return loss
    return weighted_loss

# Example usage of the weighted loss function
# model.compile(optimizer='adam', loss=get_weighted_loss(pos_weights, neg_weights))
# Out:
# Percent of Tuberculosis/Normal : 20.473287916816062 %
# 0.16000000000000003 0.16000000000000003

# %%
# strategy = tf.distribute.TPUStrategy(resolver)
train_norm = train_df['labels'].value_counts()[0]
train_tb = train_df['labels'].value_counts()[1]

print('Percent of Tuberculosis/Normal : {} %'.format(100 * train_tb/train_norm))

#create positive frequency and negative frequency
freq_pos = round((train_tb/train_norm),2)
freq_neg = 1 - freq_pos

pos_weights = freq_neg
neg_weights = freq_pos
pos_contribution = freq_pos * pos_weights
neg_contribution = freq_neg * neg_weights

print(pos_contribution, neg_contribution)

# create weight loss
def get_weighted_loss(pos_weights, neg_weights, epsilon=1e-7):

    def weighted_loss(y_true, y_pred):
        # initialize loss to zero
        loss = 0.0

        # for each class, add average weighted loss for that class
        loss += K.mean(-(pos_weights *y_true * K.log(y_pred + epsilon)
                             + neg_weights* (1 - y_true) * K.log( 1 - y_pred + epsilon)))
        return loss

    return weighted_loss
# Out:
# Percent of Tuberculosis/Normal : 20.473287916816062 %
# 0.16000000000000003 0.16000000000000003

# %% [markdown]
# # Model Creation

# %% [markdown]
# ### Eff Net

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.callbacks import Callback

# Create Model Structure
img_size = (224, 224)
channels = 3
img_shape = (img_size[0], img_size[1], channels)
class_count = len(list(train_gen.class_indices.keys())) # to define number of classes in dense layer


# create pre-trained model (you can built on pretrained model such as :  efficientnet, VGG , Resnet )
# we will use efficientnetb3 from EfficientNet family.
base_model = tf.keras.applications.efficientnet.EfficientNetB0(include_top= False, weights= "imagenet", input_shape= img_shape, pooling= 'max')
# base_model.trainable = False


model = Sequential([
        base_model,
        BatchNormalization(axis= -1, momentum= 0.99, epsilon= 0.001),
        Dense(256, kernel_regularizer= regularizers.l2(l= 0.016), activity_regularizer= regularizers.l1(0.006),
                    bias_regularizer= regularizers.l1(0.006), activation= 'relu'),
        Dropout(rate= 0.45, seed= 123),
        Dense(class_count, activation= 'softmax')
])

class CustomModelCheckpoint(Callback):
    def __init__(self, filepath, monitor='val_accuracy', mode='max', verbose=1):
        super(CustomModelCheckpoint, self).__init__()
        self.filepath = filepath
        self.monitor = monitor
        self.verbose = verbose
        self.mode = mode
        self.best_val_acc = -np.Inf if mode == 'max' else np.Inf
        self.best_train_acc = -np.Inf

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        current_val_acc = logs.get(self.monitor)
        current_train_acc = logs.get('accuracy')

        if current_val_acc is None or current_train_acc is None:
            return

        # Check if current validation accuracy is the best seen so far
        if current_val_acc > self.best_val_acc:
            self.best_val_acc = current_val_acc
            self.best_train_acc = current_train_acc
            self.model.save_weights(self.filepath)
            if self.verbose > 0:
                print(f'\nEpoch {epoch + 1}: {self.monitor} improved to {current_val_acc}, saving model.')

        # If the validation accuracy is equal, check for higher training accuracy
        elif current_val_acc == self.best_val_acc and current_train_acc > self.best_train_acc:
            self.best_train_acc = current_train_acc
            self.model.save_weights(self.filepath)
            if self.verbose > 0:
                print(f'\nEpoch {epoch + 1}: {self.monitor} same as best, but training accuracy improved to {current_train_acc}, saving model.')

# Usage in model training
checkpoint = CustomModelCheckpoint(
    filepath='best_weights',
    monitor='val_accuracy',
    mode='max',
    verbose=1
)

early = EarlyStopping(monitor="val_loss",
                      mode="min",
                      patience=8)


model.compile(Adamax(learning_rate= 0.001), loss=get_weighted_loss(pos_weights, neg_weights) , metrics= ['accuracy'])

model.summary()

from tensorflow.keras.utils import plot_model

# Assuming 'model' is your defined model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
#'categorical_crossentropy'
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional  (None, 1280)              4049571
#  )
#
#  batch_normalization (Batch  (None, 1280)              5120
#  Normalization)
#
#  dense (Dense)               (None, 256)               327936
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 4383141 (16.72 MB)
# Trainable params: 4338558 (16.55 MB)
# Non-trainable params: 44583 (174.16 KB)
# _________________________________________________________________

# %%
def build_lrfn(lr_start=0.000001, lr_max=0.001,
               lr_min=0, lr_rampup_epochs=8,
               lr_sustain_epochs=0, lr_exp_decay=.8):

    def lrfn(epoch):
        if epoch < lr_rampup_epochs:
            lr = (lr_max - lr_start) / lr_rampup_epochs * epoch + lr_start
        elif epoch < lr_rampup_epochs + lr_sustain_epochs:
            lr = lr_max
        else:
            lr = (lr_max - lr_min) *\
                 lr_exp_decay**(epoch - lr_rampup_epochs\
                                - lr_sustain_epochs) + lr_min
        return lr
    return lrfn

lrfn = build_lrfn()
lr_schedule = tf.keras.callbacks.LearningRateScheduler(lrfn, verbose=True)

# %% [markdown]
# # Training

# %%
batch_size = 64   # set batch size for training
# epochs = 100   # number of all epochs in training


# history = model.fit( x=train_gen,
#                     epochs= epochs,
#                     verbose= 1,
#                     validation_data= valid_gen,
#                     validation_steps= None,
#                     callbacks=[lr_schedule, early, checkpoint],
#                     shuffle= False)

import numpy as np
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.models import load_model

history_data=[]

# Define the number of folds for cross-validation
num_folds = 5

# Initialize k-fold cross-validation
skf = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

# Initialize variables to store results
all_accuracies = []

# Perform k-fold cross-validation
fold_count = 0
for train_index, valid_index in skf.split(train_df, train_df['labels']):
    fold_count += 1
    print(f"\nTraining Fold {fold_count}")

    # Split data into training and validation sets
    train_fold, valid_fold = train_df.iloc[train_index], train_df.iloc[valid_index]

    # Data generators for this fold
    # train_gen = tr_gen.flow_from_dataframe(train_fold, x_col='filepaths', y_col='labels', target_size=img_size,
    #                                        class_mode='categorical', color_mode='rgb', shuffle=True, batch_size=batch_size)

    # valid_gen = ts_gen.flow_from_dataframe(valid_fold, x_col='filepaths', y_col='labels', target_size=img_size,
    #                                        class_mode='categorical', color_mode='rgb', shuffle=False, batch_size=batch_size)
    train_gen = tr_gen.flow_from_dataframe( train_fold, x_col= 'filepaths', y_col= 'labels', target_size= img_size, class_mode= 'categorical',
                                    color_mode= 'rgb', shuffle= True, batch_size= batch_size)

    valid_gen = ts_gen.flow_from_dataframe( valid_fold, x_col= 'filepaths', y_col= 'labels', target_size= img_size, class_mode= 'categorical',
                                    color_mode= 'rgb', shuffle= True, batch_size= batch_size)

    # Load a new instance of the model for each fold


    # Train the model

    history = model.fit(x=train_gen, epochs=25, verbose=1, validation_data=valid_gen, validation_steps=None,
                        callbacks=[lr_schedule, early, checkpoint], shuffle=False)
    history_data.append(history)
    # Evaluate on the validation set of this fold

    valid_accuracy = model.evaluate(valid_gen)[1]
    all_accuracies.append(valid_accuracy)

# Calculate and print the average accuracy across all folds
average_accuracy = np.mean(all_accuracies)
print(f'\nAverage Accuracy across all Folds: {average_accuracy}')
# Out:
# Training Fold 1
# Found 2688 validated image filenames belonging to 2 classes.
# Found 672 validated image filenames belonging to 2 classes.
#
# Epoch 1: LearningRateScheduler setting learning rate to 1e-06.
# Epoch 1/25
# 2024-08-07 14:42:03.416445: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/efficientnetb0/block2b_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1723041729.387532     187 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 42/42 [==============================] - ETA: 0s - loss: 8.2859 - accuracy: 0.4438
# Epoch 1: val_accuracy improved to 0.7321428656578064, saving model.
# 42/42 [==============================] - 73s 881ms/step - loss: 8.2859 - accuracy: 0.4438 - val_loss: 8.3374 - val_accuracy: 0.7321 - lr: 1.0000e-06
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.000125875.
# Epoch 2/25
# 42/42 [==============================] - ETA: 0s - loss: 7.8483 - accuracy: 0.6213
# Epoch 2: val_accuracy improved to 0.8333333134651184, saving model.
# 42/42 [==============================] - 33s 773ms/step - loss: 7.8483 - accuracy: 0.6213 - val_loss: 7.6997 - val_accuracy: 0.8333 - lr: 1.2587e-04
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.00025075000000000005.
# Epoch 3/25
# 42/42 [==============================] - ETA: 0s - loss: 7.1222 - accuracy: 0.7972
# Epoch 3: val_accuracy improved to 0.9017857313156128, saving model.
# 42/42 [==============================] - 33s 770ms/step - loss: 7.1222 - accuracy: 0.7972 - val_loss: 6.8875 - val_accuracy: 0.9018 - lr: 2.5075e-04
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.0003756250000000001.
# Epoch 4/25
# 42/42 [==============================] - ETA: 0s - loss: 6.2292 - accuracy: 0.8705
# Epoch 4: val_accuracy improved to 0.9315476417541504, saving model.
# 42/42 [==============================] - 33s 772ms/step - loss: 6.2292 - accuracy: 0.8705 - val_loss: 5.8737 - val_accuracy: 0.9315 - lr: 3.7563e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.0005005000000000001.
# Epoch 5/25
# 42/42 [==============================] - 32s 753ms/step - loss: 5.1845 - accuracy: 0.9003 - val_loss: 4.7851 - val_accuracy: 0.9077 - lr: 5.0050e-04
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.0006253750000000001.
# Epoch 6/25
# 42/42 [==============================] - 32s 755ms/step - loss: 4.1582 - accuracy: 0.9334 - val_loss: 3.7476 - val_accuracy: 0.9182 - lr: 6.2538e-04
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.0007502500000000002.
# Epoch 7/25
# 42/42 [==============================] - 32s 755ms/step - loss: 3.2952 - accuracy: 0.9464 - val_loss: 2.9621 - val_accuracy: 0.9062 - lr: 7.5025e-04
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.0008751250000000001.
# Epoch 8/25
# 42/42 [==============================] - ETA: 0s - loss: 2.5675 - accuracy: 0.9598
# Epoch 8: val_accuracy improved to 0.9434523582458496, saving model.
# 42/42 [==============================] - 33s 776ms/step - loss: 2.5675 - accuracy: 0.9598 - val_loss: 2.2875 - val_accuracy: 0.9435 - lr: 8.7512e-04
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.001.
# Epoch 9/25
# 42/42 [==============================] - 32s 758ms/step - loss: 1.9748 - accuracy: 0.9658 - val_loss: 1.7583 - val_accuracy: 0.9405 - lr: 0.0010
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.0008.
# Epoch
-04
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.001.
# Epoch 9/25
# 42/42 [==============================] - 33s 780ms/step - loss: 0.0644 - accuracy: 0.9929 - val_loss: 0.0584 - val_accuracy: 0.9911 - lr: 0.0010
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.0008.
# Epoch 10/25
# 42/42 [==============================] - 33s 776ms/step - loss: 0.0591 - accuracy: 0.9963 - val_loss: 0.0495 - val_accuracy: 0.9926 - lr: 8.0000e-04
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.0006400000000000002.
# Epoch 11/25
# 42/42 [==============================] - 32s 760ms/step - loss: 0.0557 - accuracy: 0.9952 - val_loss: 0.0466 - val_accuracy: 0.9955 - lr: 6.4000e-04
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.0005120000000000001.
# Epoch 12/25
# 42/42 [==============================] - 32s 760ms/step - loss: 0.0530 - accuracy: 0.9974 - val_loss: 0.0495 - val_accuracy: 0.9955 - lr: 5.1200e-04
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.0004096000000000001.
# Epoch 13/25
# 42/42 [==============================] - 32s 756ms/step - loss: 0.0504 - accuracy: 0.9974 - val_loss: 0.0433 - val_accuracy: 0.9970 - lr: 4.0960e-04
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.0003276800000000001.
# Epoch 14/25
# 42/42 [==============================] - 32s 760ms/step - loss: 0.0480 - accuracy: 0.9989 - val_loss: 0.0421 - val_accuracy: 0.9970 - lr: 3.2768e-04
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.0002621440000000001.
# Epoch 15/25
# 42/42 [==============================] - 32s 760ms/step - loss: 0.0508 - accuracy: 0.9955 - val_loss: 0.0425 - val_accuracy: 0.9955 - lr: 2.6214e-04
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.0002097152000000001.
# Epoch 16/25
# 42/42 [==============================] - 32s 755ms/step - loss: 0.0478 - accuracy: 0.9989 - val_loss: 0.0438 - val_accuracy: 0.9940 - lr: 2.0972e-04
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.0001677721600000001.
# Epoch 17/25
# 42/42 [==============================] - 32s 748ms/step - loss: 0.0479 - accuracy: 0.9993 - val_loss: 0.0430 - val_accuracy: 0.9940 - lr: 1.6777e-04
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.00013421772800000008.
# Epoch 18/25
# 42/42 [==============================] - 32s 755ms/step - loss: 0.0481 - accuracy: 0.9981 - val_loss: 0.0440 - val_accuracy: 0.9940 - lr: 1.3422e-04
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.00010737418240000006.
# Epoch 19/25
# 42/42 [==============================] - 32s 752ms/step - loss: 0.0466 - accuracy: 0.9985 - val_loss: 0.0432 - val_accuracy: 0.9940 - lr: 1.0737e-04
#
# Epoch 20: LearningRateScheduler setting learning rate to 8.589934592000005e-05.
# Epoch 20/25
# 42/42 [==============================] - 32s 755ms/step - loss: 0.0467 - accuracy: 0.9989 - val_loss: 0.0426 - val_accuracy: 0.9926 - lr: 8.5899e-05
#
# Epoch 21: LearningRateScheduler setting learning rate to 6.871947673600005e-05.
# Epoch 21/25
# 42/42 [==============================] - 32s 753ms/step - loss: 0.0465 - accuracy: 0.9981 - val_loss: 0.0426 - val_accuracy: 0.9926 - lr: 6.8719e-05
#
# Epoch 22: LearningRateScheduler setting learning rate to 5.497558138880004e-05.
# Epoch 22/25
# 42/42 [==============================] - 32s 755ms/step - loss: 0.0454 - accuracy: 0.9993 - val_loss: 0.0424 - val_accuracy: 0.9940 - lr: 5.4976e-05
# 11/11 [==============================] - 2s 126ms/step - loss: 0.0424 - accuracy: 0.9940
#
# Training Fold 5
# Found 2688 validated image filenames belonging to 2 classes.
# Found 672 validated image filenames belonging to 2 classes.
#
# Epoch 1: LearningRateScheduler setting learning rate to 1e-06.
# Epoch 1/25
# 42/42 [==============================] - ETA: 0s - loss: 0.0468 - accuracy: 0.9985
# Epoch 1: val_accuracy same as best, but training accuracy improved to 0.9985119104385376, saving model.
# 42/42 [==============================] - 33s 774ms/step - loss: 0.0468 - accuracy: 0.9985 - val_loss: 0.0395 - val_accuracy: 0.9985 - lr: 1.0000e-06
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.000125875.
# Epoch 2/25
# 42/42 [==============================] - 32s 753ms/step - loss: 0.0475 - accuracy: 0.9981 - val_loss: 0.0395 - val_accuracy: 0.9985 - lr: 1.2587e-04
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.00025075000000000005.
# Epoch 3/25
# 42/42 [==============================] - 32s 754ms/step - loss: 0.0468 - accuracy: 0.9985 - val_loss: 0.0416 - val_accuracy: 0.9970 - lr: 2.5075e-04
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.0003756250000000001.
# Epoch 4/25
# 42/42 [==============================] - ETA: 0s - loss: 0.0463 - accuracy: 0.9989
# Epoch 4: val_accuracy same as best, but training accuracy improved to 0.9988839030265808, saving model.
# 42/42 [==============================] - 33s 773ms/step - loss: 0.0463 - accuracy: 0.9989 - val_loss: 0.0396 - val_accuracy: 0.9985 - lr: 3.7563e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.0005005000000000001.
# Epoch 5/25
# 42/42 [==============================] - 32s 758ms/step - loss: 0.0468 - accuracy: 0.9981 - val_loss: 0.0403 - val_accuracy: 0.9985 - lr: 5.0050e-04
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.0006253750000000001.
# Epoch 6/25
# 42/42 [==============================] - 32s 750ms/step - loss: 0.0479 - accuracy: 0.9970 - val_loss: 0.0465 - val_accuracy: 0.9955 - lr: 6.2538e-04
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.0007502500000000002.
# Epoch 7/25
# 42/42 [==============================] - 32s 754ms/step - loss: 0.0483 - accuracy: 0.9967 - val_loss: 0.0510 - val_accuracy: 0.9851 - lr: 7.5025e-04
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.0008751250000000001.
# Epoch 8/25
# 42/42 [==============================] - 32s 755ms/step - loss: 0.0505 - accuracy: 0.9940 - val_loss: 0.0386 - val_accuracy: 0.9985 - lr: 8.7512e-04
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.001.
# Epoch 9/25
# 42/42 [==============================] - ETA: 0s - loss: 0.0502 - accuracy: 0.9963
# Epoch 9: val_accuracy improved to 1.0, saving model.
# 42/42 [==============================] - 33s 768ms/step - loss: 0.0502 - accuracy: 0.9963 - val_loss: 0.0384 - val_accuracy: 1.0000 - lr: 0.0010
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.0008.
# Epoch 10/25
# 42/42 [==============================] - 32s 752ms/step - loss: 0.0450 - accuracy: 0.9981 - val_loss: 0.0375 - val_accuracy: 0.9985 - lr: 8.0000e-04
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.0006400000000000002.
# Epoch 11/25
# 42/42 [==============================] - 32s 753ms/step - loss: 0.0464 - accuracy: 0.9955 - val_loss: 0.0399 - val_accuracy: 0.9970 - lr: 6.4000e-04
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.0005120000000000001.
# Epoch 12/25
# 42/42 [==============================] - ETA: 0s - loss: 0.0420 - accuracy: 0.9981
# Epoch 12: val_accuracy same as best, but training accuracy improved to 0.9981398582458496, saving model.
# 42/42 [==============================] - 33s 773ms/step - loss: 0.0420 - accuracy: 0.9981 - val_loss: 0.0344 - val_accuracy: 1.0000 - lr: 5.1200e-04
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.0004096000000000001.
# Epoch 13/25
# 42/42 [==============================] - 32s 757ms/step - loss: 0.0429 - accuracy: 0.9963 - val_loss: 0.0335 - val_accuracy: 1.0000 - lr: 4.0960e-04
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.0003276800000000001.
# Epoch 14/25
# 42/42 [==============================] - ETA: 0s - loss: 0.0407 - accuracy: 0.9996
# Epoch 14: val_accuracy same as best, but training accuracy improved to 0.999627947807312, saving model.
# 42/42 [==============================] - 33s 769ms/step - loss: 0.0407 - accuracy: 0.9996 - val_loss: 0.0332 - val_accuracy: 1.0000 - lr: 3.2768e-04
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.0002621440000000001.
# Epoch 15/25
# 42/42 [==============================] - 32s 759ms/step - loss: 0.0405 - accuracy: 0.9985 - val_loss: 0.0332 - val_accuracy: 1.0000 - lr: 2.6214e-04
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.0002097152000000001.
# Epoch 16/25
# 42/42 [==============================] - 32s 757ms/step - loss: 0.0413 - accuracy: 0.9989 - val_loss: 0.0329 - val_accuracy: 1.0000 - lr: 2.0972e-04
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.0001677721600000001.
# Epoch 17/25
# 42/42 [==============================] - 32s 754ms/step - loss: 0.0395 - accuracy: 0.9989 - val_loss: 0.0326 - val_accuracy: 1.0000 - lr: 1.6777e-04
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.00013421772800000008.
# Epoch 18/25
# 42/42 [==============================] - 32s 749ms/step - loss: 0.0391 - accuracy: 0.9989 - val_loss: 0.0324 - val_accuracy: 1.0000 - lr: 1.3422e-04
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.00010737418240000006.
# Epoch 19/25
# 42/42 [==============================] - 32s 751ms/step - loss: 0.0390 - accuracy: 0.9993 - val_loss: 0.0322 - val_accuracy: 1.0000 - lr: 1.0737e-04
#
# Epoch 20: LearningRateScheduler setting learning rate to 8.589934592000005e-05.
# Epoch 20/25
# 42/42 [==============================] - 32s 749ms/step - loss: 0.0388 - accuracy: 0.9993 - val_loss: 0.0322 - val_accuracy: 1.0000 - lr: 8.5899e-05
#
# Epoch 21: LearningRateScheduler setting learning rate to 6.871947673600005e-05.
# Epoch 21/25
# 42/42 [==============================] - 32s 751ms/step - loss: 0.0377 - accuracy: 0.9996 - val_loss: 0.0321 - val_accuracy: 1.0000 - lr: 6.8719e-05
#
# Epoch 22: LearningRateScheduler setting learning rate to 5.497558138880004e-05.
# Epoch 22/25
# 42/42 [==============================] - 33s 774ms/step - loss: 0.0390 - accuracy: 0.9985 - val_loss: 0.0320 - val_accuracy: 1.0000 - lr: 5.4976e-05
#
# Epoch 23: LearningRateScheduler setting learning rate to 4.398046511104004e-05.
# Epoch 23/25
# 42/42 [==============================] - 32s 749ms/step - loss: 0.0395 - accuracy: 0.9985 - val_loss: 0.0319 - val_accuracy: 1.0000 - lr: 4.3980e-05
#
# Epoch 24: LearningRateScheduler setting learning rate to 3.518437208883203e-05.
# Epoch 24/25
# 42/42 [==============================] - 32s 755ms/step - loss: 0.0383 - accuracy: 0.9985 - val_loss: 0.0319 - val_accuracy: 1.0000 - lr: 3.5184e-05
#
# Epoch 25: LearningRateScheduler setting learning rate to 2.8147497671065623e-05.
# Epoch 25/25
# 42/42 [==============================] - 32s 750ms/step - loss: 0.0386 - accuracy: 0.9993 - val_loss: 0.0319 - val_accuracy: 1.0000 - lr: 2.8147e-05
# 11/11 [==============================] - 2s 144ms/step - loss: 0.0319 - accuracy: 1.0000
#
# Average Accuracy across all Folds: 0.9913690567016602

# %% [markdown]
# # Weight Load

# %%
model.save_weights('/kaggle/working//Merge_bw.h5')

# %%
#model.load_weights("/content/best_weight.h5")
model.load_weights('best_weights');

# %% [markdown]
# ## Model Performance

# %%
tr_acc=[]
tr_loss=[]
val_acc=[]
val_loss=[]
for history in history_data:
  n=len(history.history['accuracy'])
  for i in range(n):
    tr_acc.append(history.history['accuracy'][i])
    tr_loss.append(history.history['loss'][i])
    val_acc.append(history.history['val_accuracy'][i])
    val_loss.append(history.history['val_loss'][i])

index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmax(val_acc)
acc_highest = val_acc[index_acc]
Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'

# Plot training history
plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.show()

# %% [markdown]
# **Evaluation**

# %%
ts_length = len(test_df)
test_batch_size = max(sorted([ts_length // n for n in range(1, ts_length + 1) if ts_length%n == 0 and ts_length/n <= 80]))
test_steps = ts_length // test_batch_size

train_score = model.evaluate(train_gen, steps= test_steps, verbose= 1)
valid_score = model.evaluate(valid_gen, steps= test_steps, verbose= 1)
test_score = model.evaluate(test_gen, steps= test_steps, verbose= 1)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print("Validation Loss: ", valid_score[0])
print("Validation Accuracy: ", valid_score[1])
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
# Out:
# 12/12 [==============================] - 9s 700ms/step - loss: 0.0317 - accuracy: 1.0000
# 12/12 [==============================] - 2s 123ms/step - loss: 0.0319 - accuracy: 1.0000
# 12/12 [==============================] - 2s 33ms/step - loss: 0.0404 - accuracy: 0.9948
# Train Loss:  0.03173356503248215
# Train Accuracy:  1.0
# --------------------
# Validation Loss:  0.03193141892552376
# Validation Accuracy:  1.0
# --------------------
# Test Loss:  0.04036826640367508
# Test Accuracy:  0.9947916865348816

# %% [markdown]
# # Predictions

# %%
preds = model.predict_generator(test_gen)
y_pred = np.argmax(preds, axis=1)

# %% [markdown]
# **Report**

# %%
g_dict = test_gen.class_indices
classes = list(g_dict.keys())

# Confusion matrix
cm = confusion_matrix(test_gen.classes, y_pred)

plt.figure(figsize= (10, 10))
plt.imshow(cm, interpolation= 'nearest', cmap= plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation= 45)
plt.yticks(tick_marks, classes)


thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j], horizontalalignment= 'center', color= 'white' if cm[i, j] > thresh else 'black')

plt.tight_layout()
plt.ylabel('True Label')
plt.xlabel('Predicted Label')

plt.show()

# %%
# Classification report
print(classification_report(test_gen.classes, y_pred, target_names= classes))
